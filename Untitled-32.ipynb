# %%
#....HEADER...
print("><"*20)
print("🧮📚 WELCOME TO MY CALCULATOR 🧮📚")
print("><"*20)
# Out:
# ><><><><><><><><><><><><><><><><><><><><
# 🧮📚 WELCOME TO MY CALCULATOR 🧮📚
# ><><><><><><><><><><><><><><><><><><><><

# %%
#take the input from user and cast to float
num1 = float(input("Enter your first number"))
num2 = float (input("Enter your second number"))

# %%
#doing calculations with arithmetic operators
add = num1 + num2 
sub = num1-num2
mult = num1*num2
divide = num1/num2
flr_div = num1//num2
mod = num1%num2
exp = num1 ** num2
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[6], line 8
#       4 mult = num1*num2
#       5 divide = num1/num2
#       6 flr_div = num1//num2
#       7 mod = num1%num2
# ----> 8 exp = num1 **num2
#
# OverflowError: (34, 'Result too large')

# %%
#end results
print("/n=======RESULTS==========")
print (f"num1 + num2 = {add}")
print(f"num1 - num2 = {sub}")
print (f"num1 / num2 = {divide}")
print(f"num1 //num2 = {flr_div}")
print(f"num modulus num2 = {mod}")
print(f"num1 exponent num2 = {exp})
      print("=====================")
# Out:
#   Cell In[7], line 8
#     print(f"num1 exponent num2 = {exp})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 8)

# %%
print("Thanks for using my calculator, made with python😉")
print("#code with ai")
